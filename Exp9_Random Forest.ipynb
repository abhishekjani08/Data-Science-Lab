# %%
# Import necessary packages,Pandas is used for data manipulation
import pandas as pd
import numpy as np
# Read in data and display first 5 rows
features = pd.read_csv('loan_data_set2.csv')
features.head(5)
# Out:
#    Loa0_ID  Ge0der  Married  Depe0de0ts  Self_Emplo1ed  Applica0tI0come  \
# 0     1002     1.0      0.0         0.0            0.0             5849
# 1     1003     1.0      1.0         1.0            0.0             4583
# 2     1005     1.0      1.0         0.0            1.0             3000
# 3     1006     1.0      1.0         0.0            0.0             2583
# 4     1008     1.0      0.0         0.0            0.0             6000
#
#    Coapplica0tI0come  Loa0Amou0t  Loa0_Amou0t_Term  Credit_Histor1  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Propert1_Area  Loa0_Status
# 0              1            1
# 1              3            0
# 2              1            1
# 3              1            1
# 4              1            1

# %%
features = features.dropna()

# %%
print('The shape of our features is:', features.shape)
# Descriptive statistics for each column
features.describe()
# Out:
# The shape of our features is: (480, 12)
#            Loa0_ID      Ge0der     Married  Depe0de0ts  Self_Emplo1ed  \
# count   480.000000  480.000000  480.000000  480.000000     480.000000
# mean   2002.158333    0.820833    0.647917    0.777083       0.137500
# std     566.898488    0.383892    0.478118    1.020815       0.344734
# min    1003.000000    0.000000    0.000000    0.000000       0.000000
# 25%    1535.750000    1.000000    0.000000    0.000000       0.000000
# 50%    1975.500000    1.000000    1.000000    0.000000       0.000000
# 75%    2475.750000    1.000000    1.000000    2.000000       0.000000
# max    2990.000000    1.000000    1.000000    3.000000       1.000000
#
#        Applica0tI0come  Coapplica0tI0come  Loa0Amou0t  Loa0_Amou0t_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_Histor1  Propert1_Area  Loa0_Status
# count      480.000000     480.000000   480.000000
# mean         0.854167       1.977083     0.691667
# std          0.353307       0.776411     0.462287
# min          0.000000       1.000000     0.000000
# 25%          1.000000       1.000000     0.000000
# 50%          1.000000       2.000000     1.000000
# 75%          1.000000       3.000000     1.000000
# max          1.000000       3.000000     1.000000

# %%
# One-hot encode the data using pandas get_dummies
features = pd.get_dummies(features)
# Display the first 5 rows of the last 12 columns
features.iloc[:,5:].head(5)
# Out:
#    Applica0tI0come  Coapplica0tI0come  Loa0Amou0t  Loa0_Amou0t_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_Histor1  Propert1_Area  Loa0_Status
# 1             1.0              3            0
# 2             1.0              1            1
# 3             1.0              1            1
# 4             1.0              1            1
# 5             1.0              1            1

# %%
# Use numpy to convert to arrays
# Labels are the values we want to predict
labels = np.array(features['Loa0_Status'])
# Remove the labels from the features
# axis 1 refers to the columns
features= features.drop('Loa0_Status', axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 30)
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (360, 11)
# Training Labels Shape: (360,)
# Testing Features Shape: (120, 11)
# Testing Labels Shape: (120,)

# %%
# The baseline predictions are the historical averages
baseline_preds = test_features[:, feature_list.index('Applica0tI0come')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# Average baseline error:  5681.95

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 0.3

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors/test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: -inf %.
# <ipython-input-28-53c70cdc04e7>:4: RuntimeWarning: divide by zero encountered in divide
#   accuracy = 100 - np.mean(100*errors/test_labels)
